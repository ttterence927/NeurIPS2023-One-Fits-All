# %%
import pandas as pd
import numpy as np
data = pd.read_pickle('ttf.data')

# %%
data
# Out:
#                      open_ttf  high_ttf  low_ttf  close_ttf  volume_ttf  \
# 2016-08-10 18:00:00    12.600    12.600   12.600     12.600       200.0
# 2016-08-10 19:00:00    12.000    12.000   11.750     11.900       741.0
# 2016-08-10 20:00:00    11.950    12.000   11.950     12.000       560.0
# 2016-08-10 21:00:00    12.200    12.225   12.000     12.000       300.0
# 2016-08-10 22:00:00    12.400    12.450   12.025     12.250       177.0
# ...                       ...       ...      ...        ...         ...
# 2023-09-17 18:00:00    35.500    35.500   34.925     34.975       337.0
# 2023-09-17 19:00:00    35.000    35.300   35.000     35.300       740.0
# 2023-09-17 20:00:00    34.975    35.300   34.975     35.000       654.0
# 2023-09-17 21:00:00    35.000    35.250   35.000     35.000      1234.0
# 2023-09-17 22:00:00    35.000    35.000   34.900     34.900       452.0
#
#                      buy_ttf  sell_ttf  imbalance_ttf   open_sbs   high_sbs  \
# ...
